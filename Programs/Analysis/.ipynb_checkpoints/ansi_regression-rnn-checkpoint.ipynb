# %% [markdown]
# # ANSI Application analysis

# %%
import numpy
import pandas
import matplotlib.pyplot as plotter
from scipy.stats import pearsonr
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
def view_boxplot(df):
    # %matplotlib
    df.boxplot()
    plotter.show()

# %% [markdown]
# ## CPU data

# %%
cpu_df = pandas.read_csv('data/ansi_fake_data/ansi_fake_data_cpu.csv', index_col='Time').drop('Unnamed: 0', axis=1)

# %%
#cpu_df.columns

# %%
#view_boxplot(cpu_df)

# %% [markdown]
# ## Network TX

# %%
txnet_df = pandas.read_csv('data/ansi_fake_data/ansi_fake_data_network_tx.csv', index_col='Time').drop('Unnamed: 0', axis=1)

# %%
#txnet_df.columns

# %%
#view_boxplot(txnet_df)

# %% [markdown]
# ## Network RX

# %%
rxnet_df = pandas.read_csv('data/ansi_fake_data/ansi_fake_data_network_rx.csv', index_col='Time').drop('Unnamed: 0', axis=1)

# %%
#rxnet_df.columns

# %%
rxnet_df = rxnet_df.clip(lower=0, upper=15000)
#view_boxplot(rxnet_df)

# %% [markdown]
# ## Disk IO data

# %%
disk_df = pandas.read_csv('data/ansi_fake_data/ansi_fake_data_disk_io.csv', index_col='Time').drop('Unnamed: 0', axis=1)

# %%
#disk_df.columns

# %%
disk_df = disk_df.clip(lower=0, upper=4000)
#view_boxplot(disk_df)

# %% [markdown]
# ## Context switching

# %%
context_df = pandas.read_csv('data/ansi_fake_data/ansi_fake_data_context.csv', index_col='Time').drop('Unnamed: 0', axis=1)

# %%
#context_df.columns

# %%
context_df = context_df.clip(lower=0, upper=5000)
#view_boxplot(context_df)

# %% [markdown]
# ## Seperate into proper dataframes for each node

# %%
dframes = [cpu_df, txnet_df, rxnet_df, context_df, disk_df]
node = {}

for i in range(1,5):
    frames = []
    
    for dframe in dframes:
        columns = list(filter(lambda x: f'bb{i}l' in x, dframe.columns))
        frames.append(dframe[columns])

    node[i] = pandas.concat(frames, join='inner', axis=1).fillna(0)[:38200]

# %%
for i in range(1,5):
    print(node[i].shape)
    
print(node[1].columns)
# Out:
# (38200, 29)
# (38200, 29)
# (38200, 29)
# (38200, 29)
# Index(['cpu_value host bb1localdomain type_instance idle',
#        'cpu_value host bb1localdomain type_instance interrupt',
#        'cpu_value host bb1localdomain type_instance nice',
#        'cpu_value host bb1localdomain type_instance softirq',
#        'cpu_value host bb1localdomain type_instance steal',
#        'cpu_value host bb1localdomain type_instance system',
#        'cpu_value host bb1localdomain type_instance user',
#        'cpu_value host bb1localdomain type_instance wait',
#        'interface_tx host bb1localdomain instance lo type if_dropped',
#        'interface_tx host bb1localdomain instance lo type if_errors',
#        'interface_tx host bb1localdomain instance lo type if_octets',
#        'interface_tx host bb1localdomain instance lo type if_packets',
#        'interface_tx host bb1localdomain instance wlan0 type if_dropped',
#        'interface_tx host bb1localdomain instance wlan0 type if_errors',
#        'interface_tx host bb1localdomain instance wlan0 type if_octets',
#        'interface_tx host bb1localdomain instance wlan0 type if_packets',
#        'interface_rx host bb1localdomain instance lo type if_dropped',
#        'interface_rx host bb1localdomain instance lo type if_errors',
#        'interface_rx host bb1localdomain instance lo type if_octets',
#        'interface_rx host bb1localdomain instance lo type if_packets',
#        'interface_rx host bb1localdomain instance wlan0 type if_dropped',
#        'interface_rx host bb1localdomain instance wlan0 type if_errors',
#        'interface_rx host bb1localdomain instance wlan0 type if_octets',
#        'interface_rx host bb1localdomain instance wlan0 type if_packets',
#        'contextswitch_value host bb1localdomain type contextswitch',
#        'disk_io_time host bb1localdomain instance mmcblk1 type disk_io_time',
#        'disk_io_time host bb1localdomain instance mmcblk1boot0 type disk_io_time',
#        'disk_io_time host bb1localdomain instance mmcblk1boot1 type disk_io_time',
#        'disk_io_time host bb1localdomain instance mmcblk1p1 type disk_io_time'],
#       dtype='object')

# %% [markdown]
# ## Get data

# %%
data_matrices = []

for i in range(1,5):
    data_matrices.append(node[i].as_matrix())
    
data = numpy.vstack(data_matrices)

# %%
data.shape
# Out:
# (152800, 29)

# %%
tdata = data[:,24]
plotter.plot(tdata.T[:100])
plotter.show()
print(data.shape)
# Out:
# (152800, 29)

# %%
#data = data[:,24]

# %% [markdown]
# ## Prepare scaler

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import RobustScaler
scaler = MinMaxScaler()

# %%
scaler.fit(data)
del data

# %% [markdown]
# ---

# %% [markdown]
# ## Correrlation measurement

# %% [markdown]
# ---

# %% [markdown]
# ------

# %% [markdown]
# -----

# %% [markdown]
# # Prediction

# %%
for i in range(len(data_matrices)):
    
    transformed = scaler.transform(data_matrices[i])
    data_matrices[i] = transformed

X = numpy.stack(data_matrices[:-1], axis=1)
test_X = numpy.array([data_matrices[3]])
test_X[0,50,0] = 1.0
#x_val = numpy.array([data_matrices[2]])

# %%
plotter.plot(test_X.squeeze()[:100])
plotter.show()

# %%
print(X.shape)
LEN = X.shape[0]
SPLIT = int(0.9*LEN)

train_X = X[:SPLIT,:,:]
val_X = X[SPLIT:SPLIT+1000,:,:]
test_X = X[SPLIT+1000:,:,:]
# Out:
# (38200, 3, 29)

# %%
X = train_X
X = numpy.transpose(X, (1, 0, 2))
#X = X.reshape((-1,382,29))
val_X = numpy.transpose(val_X, (1, 0, 2))
test_X = numpy.transpose(test_X, (1, 0, 2))
#val_X = val_X.reshape((-1,382,29))
print(X.shape)
print(val_X.shape)
# Out:
# (3, 34380, 29)
# (3, 1000, 29)

# %%
plotter.plot(test_X[0][:,25])
plotter.show()
#test_X[0][:,25] = 0.0
#test_X[0][:,28] = 0.0
plotter.plot(test_X[0][:,25])
plotter.show()

# %%
def flat_generator(X, tsteps = 5, ravel=1):
    i = 0
    
    while True:
        batch_X = X[:,i:i+tsteps,:]
        batch_y = X[:,i+tsteps,:]
            
        if ravel:
            batch_X = batch_X.reshape((batch_X.shape[0], -1))
        #print(batch_X.shape)
        #print(batch_y.shape)
        
        yield batch_X, batch_y
        
        i += 1
        if i > (X.shape[1] - tsteps - 1):
            i = 0
            continue

# %%
TIMESTEPS = 10
DIM = 29
tgen = flat_generator(X, TIMESTEPS)
vgen = flat_generator(val_X, TIMESTEPS)

# %% [markdown]
# ## Flat models

# %% [markdown]
# ### Linear Regression

# %%
from keras.models import Model
from keras.layers import Dense, Input, Dropout, GRU
from keras.callbacks import EarlyStopping
# Out:
# Using TensorFlow backend.

# %%
input_layer = Input(shape=(TIMESTEPS*DIM,))
#hidden = Dense(1000, activation='relu')(input_layer)
#hidden = Dense(500, activation='relu')(input_layer)
#hidden = Dense(90, activation='relu')(hidden)
#hidden = Dense(50, activation='relu')(hidden)
output = Dense(DIM, activation='sigmoid')(input_layer)

# %%
model = Model(input_layer, output)

# %%
estopper = EarlyStopping(patience=10, min_delta=0.0001)
model.compile(loss='mean_absolute_error', optimizer='adam', metrics=['mae'])

# %%
history = model.fit_generator(tgen, steps_per_epoch=1000, epochs=10000, callbacks=[estopper], shuffle=False, validation_data=vgen, validation_steps=1000)
plotter.plot(history.history['loss'],label='train')
plotter.plot(history.history['val_loss'],label='validation')
plotter.legend()
plotter.show()
# Out:
# Epoch 1/10000
# 1000/1000 [==============================] - 4s 4ms/step - loss: 0.0495 - mean_absolute_error: 0.0495 - val_loss: 0.0156 - val_mean_absolute_error: 0.0156
# Epoch 2/10000
# 1000/1000 [==============================] - 4s 4ms/step - loss: 0.0142 - mean_absolute_error: 0.0142 - val_loss: 0.0125 - val_mean_absolute_error: 0.0125
# Epoch 3/10000
# 1000/1000 [==============================] - 4s 4ms/step - loss: 0.0125 - mean_absolute_error: 0.0125 - val_loss: 0.0116 - val_mean_absolute_error: 0.0116
# Epoch 4/10000
# 1000/1000 [==============================] - 3s 3ms/step - loss: 0.0118 - mean_absolute_error: 0.0118 - val_loss: 0.0111 - val_mean_absolute_error: 0.0111
# Epoch 5/10000
# 1000/1000 [==============================] - 4s 4ms/step - loss: 0.0113 - mean_absolute_error: 0.0113 - val_loss: 0.0112 - val_mean_absolute_error: 0.0112
# Epoch 6/10000
# 1000/1000 [==============================] - 4s 4ms/step - loss: 0.0111 - mean_absolute_error: 0.0111 - val_loss: 0.0109 - val_mean_absolute_error: 0.0109
# Epoch 7/10000
# 1000/1000 [==============================] - 4s 4ms/step - loss: 0.0112 - mean_absolute_error: 0.0112 - val_loss: 0.0108 - val_mean_absolute_error: 0.0108
# Epoch 8/10000
# 1000/1000 [==============================] - 4s 4ms/step - loss: 0.0110 - mean_absolute_error: 0.0110 - val_loss: 0.0108 - val_mean_absolute_error: 0.0108
# Epoch 9/10000
# 1000/1000 [==============================] - 3s 3ms/step - loss: 0.0107 - mean_absolute_error: 0.0107 - val_loss: 0.0107 - val_mean_absolute_error: 0.0107
# Epoch 10/10000
# 1000/1000 [==============================] - 3s 3ms/step - loss: 0.0110 - mean_absolute_error: 0.0110 - val_loss: 0.0106 - val_mean_absolute_error: 0.0106
# Epoch 11/10000
# 1000/1000 [==============================] - 4s 4ms/step - loss: 0.0108 - mean_absolute_error: 0.0108 - val_loss: 0.0106 - val_mean_absolute_error: 0.0106
# Epoch 12/10000
# 1000/1000 [==============================] - 4s 4ms/step - loss: 0.0107 - mean_absolute_error: 0.0107 - val_loss: 0.0105 - val_mean_absolute_error: 0.0105
# Epoch 13/10000
# 1000/1000 [==============================] - 4s 4ms/step - loss: 0.0106 - mean_absolute_error: 0.0106 - val_loss: 0.0105 - val_mean_absolute_error: 0.0105
# Epoch 14/10000
# 1000/1000 [==============================] - 4s 4ms/step - loss: 0.0102 - mean_absolute_error: 0.0102 - val_loss: 0.0105 - val_mean_absolute_error: 0.0105
# Epoch 15/10000
# 1000/1000 [==============================] - 4s 4ms/step - loss: 0.0109 - mean_absolute_error: 0.0109 - val_loss: 0.0105 - val_mean_absolute_error: 0.0105
# Epoch 16/10000
# 1000/1000 [==============================] - 4s 4ms/step - loss: 0.0107 - mean_absolute_error: 0.0107 - val_loss: 0.0106 - val_mean_absolute_error: 0.0106
# Epoch 17/10000
# 1000/1000 [==============================] - 4s 4ms/step - loss: 0.0107 - mean_absolute_error: 0.0107 - val_loss: 0.0104 - val_mean_absolute_error: 0.0104
# Epoch 18/10000
# 1000/1000 [==============================] - 4s 4ms/step - loss: 0.0111 - mean_absolute_error: 0.0111 - val_loss: 0.0103 - val_mean_absolute_error: 0.0103
# Epoch 19/10000
# 1000/1000 [==============================] - 4s 4ms/step - loss: 0.0121 - mean_absolute_error: 0.0121 - val_loss: 0.0103 - val_mean_absolute_error: 0.0103
# Epoch 20/10000
# 1000/1000 [==============================] - 4s 4ms/step - loss: 0.0108 - mean_absolute_error: 0.0108 - val_loss: 0.0104 - val_mean_absolute_error: 0.0104
# Epoch 21/10000
# 1000/1000 [==============================] - 4s 4ms/step - loss: 0.0107 - mean_absolute_error: 0.0107 - val_loss: 0.0104 - val_mean_absolute_error: 0.0104
# Epoch 22/10000
# 1000/1000 [==============================] - 4s 4ms/step - loss: 0.0107 - mean_absolute_error: 0.0107 - val_loss: 0.0104 - val_mean_absolute_error: 0.0104
# Epoch 23/10000
# 1000/1000 [==============================] - 4s 4ms/step - loss: 0.0107 - mean_absolute_error: 0.0107 - val_loss: 0.0103 - val_mean_absolute_error: 0.0103
# Epoch 24/10000
# 1000/1000 [==============================] - 3s 3ms/step - loss: 0.0106 - mean_absolute_error: 0.0106 - val_loss: 0.0103 - val_mean_absolute_error: 0.0103
# Epoch 25/10000
# 1000/1000 [==============================] - 4s 4ms/step - loss: 0.0106 - mean_absolute_error: 0.0106 - val_loss: 0.0104 - val_mean_absolute_error: 0.0104
# Epoch 26/10000
# 1000/1000 [==============================] - 3s 3ms/step - loss: 0.0104 - mean_absolute_error: 0.0104 - val_loss: 0.0103 - val_mean_absolute_error: 0.0103
# Epoch 27/10000
# 1000/1000 [==============================] - 3s 3ms/step - loss: 0.0106 - mean_absolute_error: 0.0106 - val_loss: 0.0104 - val_mean_absolute_error: 0.0104
# Epoch 28/10000
# 1000/1000 [==============================] - 4s 4ms/step - loss: 0.0104 - mean_absolute_error: 0.0104 - val_loss: 0.0103 - val_mean_absolute_error: 0.0103

# %%
test_gen = flat_generator(numpy.array([test_X[0]]), TIMESTEPS,0)
error = []
targets = []
preds = []
for i in range(2000):
    _input,target = next(test_gen)
    
    if i != 0:
        #print(_input.shape)
        _input = _input.squeeze()[1:,:]
        #print(_input.shape)
        _input = numpy.append(pred,_input, axis=0)
        #print(_input.shape)
        
    targets.append(target.squeeze())
    pred = model.predict(_input.ravel()[:,numpy.newaxis].T)
    #print(target.shape)
    #print(pred.shape)
    preds.append(pred.squeeze())
    error.append(mean_absolute_error(y_pred=pred, y_true=target))

targets = numpy.vstack(targets)
preds = numpy.vstack(preds)

plotter.plot(error, 'g-', alpha=0.9)
plotter.show()
error = numpy.array(error)
print(numpy.mean(error))
plotter.boxplot(error)
plotter.show()
plotter.plot(targets)
plotter.show()
#print(error)
# Out:
# 0.0156256891506

# %%
print(test_X[0].shape)
plotter.plot(test_X[0][:250,6], alpha=0.3)
plotter.plot(test_X[0][:250,0], alpha=0.3)
plotter.plot(test_X[0][:250,20], alpha=0.3)
plotter.show()
plotter.plot(error[:250], alpha=0.5)
plotter.show()
# Out:
# (2820, 29)

# %%
print(X[0].shape)
plotter.plot(X[0][:,5])
plotter.show()
# Out:
# (34380, 29)
