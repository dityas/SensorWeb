# %%
import sys
sys.path.append("/home/adityas/UGA/SensorWeb/scripts/Summer2018/code")
from component import CPU, DiskIO, Network
import matplotlib.pyplot as plotter

# %%
cpu = CPU(cycles=5)
disk = DiskIO(cycles=5)
network = Network(cycles=5)

# %%
cpu_data = cpu.get_data(start=0, stop=1, noise=0.01) * 0.5
disk_data = disk.get_data(start=0, stop=1, noise=0.1)
network_data = network.get_data(start=0, stop=1, noise=0.001)

# %%
plotter.plot(cpu_data, label="CPU")
plotter.plot(disk_data, label="Disk")
plotter.plot(network_data, label="Network")
plotter.legend()
plotter.show()
